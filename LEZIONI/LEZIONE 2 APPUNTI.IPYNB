# %% [markdown]
# 📘 Day 2 – Architettura Lakehouse: concetti e vantaggi
#
# ## 🧠 Cos'è l'Architettura Lakehouse?
#
# L'**Architettura Lakehouse** è un modello innovativo introdotto da **Databricks** che unisce i vantaggi dei **data lake** (flessibilità, scalabilità, costi ridotti) con quelli dei **data warehouse** (affidabilità, governance, prestazioni).
#
# A differenza degli approcci tradizionali (es. **Lambda Architecture**, che separa streaming e batch), il Lakehouse offre una **piattaforma unica e integrata** per gestire tutti i workload dati.
#
# ---
#
# ## ✅ Vantaggi principali
#
# - Unificazione tra storage e analytics
# - Riduzione della duplicazione dei dati
# - Maggiore efficienza e semplicità architetturale
# - Supporto nativo a formati open (es. Parquet, Delta Lake)
# - Integrazione con strumenti ML/AI e BI

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Prestazioni Ottimizzate
#
# - **Ottimizzazioni Automatiche**
#   Z-Ordering, data skipping e compattazione automatica migliorano le query senza interventi manuali.
#
# - **Elasticità del Cluster**
#   Risorse di calcolo scalabili in base al carico di lavoro per cluster e job notebook.
#
# ---
#
# ### 3. Openness e Portabilità
#
# - **Formati Aperti**
#   Dati memorizzati in Parquet, accessibili anche da strumenti esterni (es. Power BI, Snowflake).
#
# - **Nessun Vendor Lock**
#   I dati possono essere letti da altre piattaforme grazie all’uso di standard aperti.
#
# ---

# %% [markdown]
# # Day2 - Architettura Lakehouse: concetti e vantaggi
#
# ## 3. Governance Centralizzata con Unity Catalog
#
# - **Controllo degli Accessi**:
#   Gestione fine-grained dei permessi a livello di tabella, colonna o riga.
#   → Permette di applicare politiche di sicurezza precise, limitando l'accesso solo ai dati necessari.
#
# - **Lineage dei Dati**:
#   Tracciamento end-to-end del flusso dei dati.
#   → Fondamentale per audit, conformità normativa (es. GDPR) e comprensione della provenienza dei dati.
#
# - **Condivisione Sicura**:
#   Delta Sharing permette di condividere dati in tempo reale con partner esterni senza duplicare lo storage.
#   → Riduce costi, migliora la collaborazione e garantisce controllo sulle informazioni condivise.

# %% [markdown]
# ## Vantaggi Principali
#
# ### ✅ Semplificazione dell'Architettura
#
# - **Elimina la Complessità**:
#   Non ci sono più pipeline separate per batch, streaming o machine learning.
#   → Tutti i workload condividono lo stesso ambiente.
#
# - **Riduzione dei Costi**:
#   Archiviazione su data lake economico (es. Azure Data Lake, S3) anziché su data warehouse proprietari costosi.
#   → Maggiore efficienza e scalabilità a basso costo.
#
# ### ✅ Affidabilità e Qualità dei Dati
#
# - **Schema Enforcement**:
#   Blocca l'inserimento di dati non conformi, prevenendo errori downstream.
#   → Garantisce integrità strutturale dei dati.
#
# - **Time Travel**:
#   Ripristina versioni precedenti dei dati in caso di errori (es. rollback di ETL falliti).
#   → Migliora la resilienza e facilita la gestione degli errori.

# %% [markdown]
# ## Collaborazione tra Team
#
# - **Stesso Dataset per Tutti**:
#   Data engineer, data scientist e analisti lavorano sugli stessi dati, riducendo silos organizzativi.
#   → Promuove una cultura di condivisione e coerenza.
#
# - **Notebook Condivisi**:
#   Documentazione integrata con codice, risultati e commenti in tempo reale.
#   → Facilita la collaborazione, il riutilizzo del lavoro e l'auditabilità.
#
# ## Prestazioni Ottimizzate
#
# - **Ottimizzazioni Automatiche**:
#   Z-Ordering, data skipping e compattazione automatica migliorano le query senza intervento manuale.
#   → Performance elevate anche su grandi volumi di dati.
#
# - **Elasticità dei Cluster**:
#   Risorse di calcolo scalabili in base al carico di lavoro (es. cluster autoscaling per job notturni).
#   → Ottimizzazione dei costi e risposta dinamica alle esigenze operative.
#
# ## Openness e Portabilità
#
# - **Formati Aperti**:
#   Dati memorizzati in Parquet, accessibili anche da strumenti esterni (es. Power BI, Snowflake).
#   → Interoperabilità con ecosistemi diversi.
#
# - **Nessun Vendor Lock-in**:
#   Possibilità di migrare i dati su altre piattaforme grazie all’uso di standard aperti.
#   → Maggiore libertà strategica e riduzione dei rischi legati a fornitori.
